# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\bhanu\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: scipy in c:\users\bhanu\anaconda3\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: matplotlib in c:\users\bhanu\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: seaborn in c:\users\bhanu\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: numpy in c:\users\bhanu\anaconda3\lib\site-packages (from missingno) (1.21.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\bhanu\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\bhanu\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bhanu\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\bhanu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics

# %%
main_data = pd.read_excel("C://Users//bhanu//Documents//summer intern//time_series_375_preprocess_en.xlsx")  #training data
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 81 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   PATIENT_ID                                                     375 non-null    float64
#  1   RE_DATE                                                        6106 non-null   datetime64[ns]
#  2   age                                                            6120 non-null   int64
#  3   gender                                                         6120 non-null   int64
#  4   Admission time                                                 6120 non-null   datetime64[ns]
#  5   Discharge time                                                 6120 non-null   datetime64[ns]
#  6   outcome                                                        6120 non-null   int64
#  7   Hypersensitive cardiac troponinI                               507 non-null    float64
#  8   hemoglobin                                                     975 non-null    float64
#  9   Serum chloride                                                 975 non-null    float64
#  10  Prothrombin time                                               662 non-null    float64
#  11  procalcitonin                                                  459 non-null    float64
#  12  eosinophils(%)                                                 957 non-null    float64
#  13  Interleukin 2 receptor                                         268 non-null    float64
#  14  Alkaline phosphatase                                           930 non-null    float64
#  15  albumin                                                        934 non-null    float64
#  16  basophil(%)                                                    957 non-null    float64
#  17  Interleukin 10                                                 267 non-null    float64
#  18  Total bilirubin                                                930 non-null    float64
#  19  Platelet count                                                 957 non-null    float64
#  20  monocytes(%)                                                   958 non-null    float64
#  21  antithrombin                                                   330 non-null    float64
#  22  Interleukin 8                                                  268 non-null    float64
#  23  indirect bilirubin                                             906 non-null    float64
#  24  Red blood cell distribution width                              923 non-null    float64
#  25  neutrophils(%)                                                 957 non-null    float64
#  26  total protein                                                  931 non-null    float64
#  27  Quantification of Treponema pallidum antibodies                279 non-null    float64
#  28  Prothrombin activity                                           659 non-null    float64
#  29  HBsAg                                                          279 non-null    float64
#  30  mean corpuscular volume                                        957 non-null    float64
#  31  hematocrit                                                     957 non-null    float64
#  32  White blood cell count                                         1127 non-null   float64
#  33  Tumor necrosis factorα                                         268 non-null    float64
#  34  mean corpuscular hemoglobin concentration                      957 non-null    float64
#  35  fibrinogen                                                     566 non-null    float64
#  36  Interleukin 1β                                                 268 non-null    float64
#  37  Urea                                                           936 non-null    float64
#  38  lymphocyte count                                               957 non-null    float64
#  39  PH value                                                       384 non-null    float64
#  40  Red blood cell count                                           1127 non-null   float64
#  41  Eosinophil count                                               957 non-null    float64
#  42  Corrected calcium                                              914 non-null    float64
#  43  Serum potassium                                                980 non-null    float64
#  44  glucose                                                        775 non-null    float64
#  45  neutrophils count                                              957 non-null    float64
#  46  Direct bilirubin                                               930 non-null    float64
#  47  Mean platelet volume                                           862 non-null    float64
#  48  ferritin                                                       283 non-null    float64
#  49  RBC distribution width SD                                      923 non-null    float64
#  50  Thrombin time                                                  566 non-null    float64
#  51  (%)lymphocyte                                                  958 non-null    float64
#  52  HCV antibody quantification                                    279 non-null    float64
#  53  D-D dimer                                                      630 non-null    float64
#  54  Total cholesterol                                              931 non-null    float64
#  55  aspartate aminotransferase                                     935 non-null    float64
#  56  Uric acid                                                      934 non-null    float64
#  57  HCO3-                                                          934 non-null    float64
#  58  calcium                                                        979 non-null    float64
#  59  Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  475 non-null    float64
#  60  Lactate dehydrogenase                                          934 non-null    float64
#  61  platelet large cell ratio                                      862 non-null    float64
#  62  Interleukin 6                                                  272 non-null    float64
#  63  Fibrin degradation products                                    330 non-null    float64
#  64  monocytes count                                                957 non-null    float64
#  65  PLT distribution width                                         862 non-null    float64
#  66  globulin                                                       930 non-null    float64
#  67  γ-glutamyl transpeptidase                                      930 non-null    float64
#  68  International standard ratio                                   659 non-null    float64
#  69  basophil count(#)                                              957 non-null    float64
#  70  2019-nCoV nucleic acid detection                               501 non-null    float64
#  71  mean corpuscular hemoglobin                                    957 non-null    float64
#  72  Activation of partial thromboplastin time                      568 non-null    float64
#  73  High sensitivity C-reactive protein                            737 non-null    float64
#  74  HIV antibody quantification                                    278 non-null    float64
#  75  serum sodium                                                   975 non-null    float64
#  76  thrombocytocrit                                                862 non-null    float64
#  77  ESR                                                            383 non-null    float64
#  78  glutamic-pyruvic transaminase                                  931 non-null    float64
#  79  eGFR                                                           936 non-null    float64
#  80  creatinine                                                     936 non-null    float64
# dtypes: datetime64[ns](3), float64(75), int64(3)
# memory usage: 3.8 MB

# %%
main_data.head()
# Out:
#    PATIENT_ID             RE_DATE  age  gender      Admission time  \
# 0         1.0 2020-01-31 01:09:00   73       1 2020-01-30 22:12:47
# 1         NaN 2020-01-31 01:25:00   73       1 2020-01-30 22:12:47
# 2         NaN 2020-01-31 01:44:00   73       1 2020-01-30 22:12:47
# 3         NaN 2020-01-31 01:45:00   73       1 2020-01-30 22:12:47
# 4         NaN 2020-01-31 01:56:00   73       1 2020-01-30 22:12:47
#
#        Discharge time  outcome  Hypersensitive cardiac troponinI  hemoglobin  \
# 0 2020-02-17 12:40:09        0                               NaN         NaN
# 1 2020-02-17 12:40:09        0                               NaN       136.0
# 2 2020-02-17 12:40:09        0                               NaN         NaN
# 3 2020-02-17 12:40:09        0                               NaN         NaN
# 4 2020-02-17 12:40:09        0                              19.9         NaN
#
#    Serum chloride  ...  mean corpuscular hemoglobin   \
# 0             NaN  ...                           NaN
# 1             NaN  ...                          31.9
# 2           103.1  ...                           NaN
# 3             NaN  ...                           NaN
# 4             NaN  ...                           NaN
#
#    Activation of partial thromboplastin time  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    High sensitivity C-reactive protein  HIV antibody quantification  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                 43.1                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
#
#    serum sodium  thrombocytocrit  ESR  glutamic-pyruvic transaminase  eGFR  \
# 0           NaN              NaN  NaN                            NaN   NaN
# 1           NaN             0.12  NaN                            NaN   NaN
# 2         137.7              NaN  NaN                           16.0  46.6
# 3           NaN              NaN  NaN                            NaN   NaN
# 4           NaN              NaN  NaN                            NaN   NaN
#
#    creatinine
# 0         NaN
# 1         NaN
# 2       130.0
# 3         NaN
# 4         NaN
#
# [5 rows x 81 columns]

# %%
# In the data, one patient has different set of values - rows. but we can see that 
# only the first row has the patient ID and the rest of the cases have NaN as the value.
# All the rows should have the same patient id. we are recognising this with the help of admission
# date as the admission date will not change for different cases. to fill Nan values we use the preceding values.
main_data['PATIENT_ID'] = [i for i in range(1,len(main_data)+1)]
main_data
# Out:
#       PATIENT_ID             RE_DATE  age  gender      Admission time  \
# 0              1 2020-01-31 01:09:00   73       1 2020-01-30 22:12:47
# 1              2 2020-01-31 01:25:00   73       1 2020-01-30 22:12:47
# 2              3 2020-01-31 01:44:00   73       1 2020-01-30 22:12:47
# 3              4 2020-01-31 01:45:00   73       1 2020-01-30 22:12:47
# 4              5 2020-01-31 01:56:00   73       1 2020-01-30 22:12:47
# ...          ...                 ...  ...     ...                 ...
# 6115        6116 2020-02-16 11:21:00   68       1 2020-02-08 23:25:01
# 6116        6117 2020-02-16 12:04:00   68       1 2020-02-08 23:25:01
# 6117        6118 2020-02-16 12:14:00   68       1 2020-02-08 23:25:01
# 6118        6119 2020-02-16 14:11:00   68       1 2020-02-08 23:25:01
# 6119        6120 2020-02-16 14:37:00   68       1 2020-02-08 23:25:01
#
#           Discharge time  outcome  Hypersensitive cardiac troponinI  \
# 0    2020-02-17 12:40:09        0                               NaN
# 1    2020-02-17 12:40:09        0                               NaN
# 2    2020-02-17 12:40:09        0                               NaN
# 3    2020-02-17 12:40:09        0                               NaN
# 4    2020-02-17 12:40:09        0                              19.9
# ...                  ...      ...                               ...
# 6115 2020-02-19 01:31:58        1                              84.9
# 6116 2020-02-19 01:31:58        1                               NaN
# 6117 2020-02-19 01:31:58        1                               NaN
# 6118 2020-02-19 01:31:58        1                               NaN
# 6119 2020-02-19 01:31:58        1                               NaN
#
#       hemoglobin  Serum chloride  ...  mean corpuscular hemoglobin   \
# 0            NaN             NaN  ...                           NaN
# 1          136.0             NaN  ...                          31.9
# 2            NaN           103.1  ...                           NaN
# 3            NaN             NaN  ...                           NaN
# 4            NaN             NaN  ...                           NaN
# ...          ...             ...  ...                           ...
# 6115         NaN             NaN  ...                           NaN
# 6116         NaN             NaN  ...                           NaN
# 6117         NaN           105.2  ...                           NaN
# 6118       155.0             NaN  ...                          31.6
# 6119         NaN             NaN  ...                           NaN
#
#       Activation of partial thromboplastin time  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 6115                                        NaN
# 6116                                        NaN
# 6117                                        NaN
# 6118                                        NaN
# 6119                                       35.8
#
#       High sensitivity C-reactive protein  HIV antibody quantification  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                    43.1                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ...                                   ...                          ...
# 6115                                  NaN                          NaN
# 6116                                  NaN                          NaN
# 6117                                267.0                          NaN
# 6118                                  NaN                          NaN
# 6119                                  NaN                          NaN
#
#       serum sodium  thrombocytocrit  ESR  glutamic-pyruvic transaminase  eGFR  \
# 0              NaN              NaN  NaN                            NaN   NaN
# 1              NaN             0.12  NaN                            NaN   NaN
# 2            137.7              NaN  NaN                           16.0  46.6
# 3              NaN              NaN  NaN                            NaN   NaN
# 4              NaN              NaN  NaN                            NaN   NaN
# ...            ...              ...  ...                            ...   ...
# 6115           NaN              NaN  NaN                            NaN   NaN
# 6116           NaN              NaN  NaN                            NaN   NaN
# 6117         139.3              NaN  NaN                           17.0  88.6
# 6118           NaN              NaN  NaN                            NaN   NaN
# 6119           NaN              NaN  NaN                            NaN   NaN
#
#       creatinine
# 0            NaN
# 1            NaN
# 2          130.0
# 3            NaN
# 4            NaN
# ...          ...
# 6115         NaN
# 6116         NaN
# 6117        77.0
# 6118         NaN
# 6119         NaN
#
# [6120 rows x 81 columns]

# %%
# As there are different set of values for each patient we are choosing the value which is most recent. 
# to do this we group the patient id and with respect to the admission time and select the last row of each group
data_1 = main_data.sort_values('RE_DATE')
data_1 = data_1.sort_values('PATIENT_ID')
data_1
# Out:
#       PATIENT_ID             RE_DATE  age  gender      Admission time  \
# 0              1 2020-01-31 01:09:00   73       1 2020-01-30 22:12:47
# 1              2 2020-01-31 01:25:00   73       1 2020-01-30 22:12:47
# 2              3 2020-01-31 01:44:00   73       1 2020-01-30 22:12:47
# 3              4 2020-01-31 01:45:00   73       1 2020-01-30 22:12:47
# 4              5 2020-01-31 01:56:00   73       1 2020-01-30 22:12:47
# ...          ...                 ...  ...     ...                 ...
# 6115        6116 2020-02-16 11:21:00   68       1 2020-02-08 23:25:01
# 6116        6117 2020-02-16 12:04:00   68       1 2020-02-08 23:25:01
# 6117        6118 2020-02-16 12:14:00   68       1 2020-02-08 23:25:01
# 6118        6119 2020-02-16 14:11:00   68       1 2020-02-08 23:25:01
# 6119        6120 2020-02-16 14:37:00   68       1 2020-02-08 23:25:01
#
#           Discharge time  outcome  Hypersensitive cardiac troponinI  \
# 0    2020-02-17 12:40:09        0                               NaN
# 1    2020-02-17 12:40:09        0                               NaN
# 2    2020-02-17 12:40:09        0                               NaN
# 3    2020-02-17 12:40:09        0                               NaN
# 4    2020-02-17 12:40:09        0                              19.9
# ...                  ...      ...                               ...
# 6115 2020-02-19 01:31:58        1                              84.9
# 6116 2020-02-19 01:31:58        1                               NaN
# 6117 2020-02-19 01:31:58        1                               NaN
# 6118 2020-02-19 01:31:58        1                               NaN
# 6119 2020-02-19 01:31:58        1                               NaN
#
#       hemoglobin  Serum chloride  ...  mean corpuscular hemoglobin   \
# 0            NaN             NaN  ...                           NaN
# 1          136.0             NaN  ...                          31.9
# 2            NaN           103.1  ...                           NaN
# 3            NaN             NaN  ...                           NaN
# 4            NaN             NaN  ...                           NaN
# ...          ...             ...  ...                           ...
# 6115         NaN             NaN  ...                           NaN
# 6116         NaN             NaN  ...                           NaN
# 6117         NaN           105.2  ...                           NaN
# 6118       155.0             NaN  ...                          31.6
# 6119         NaN             NaN  ...                           NaN
#
#       Activation of partial thromboplastin time  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 6115                                        NaN
# 6116                                        NaN
# 6117                                        NaN
# 6118                                        NaN
# 6119                                       35.8
#
#       High sensitivity C-reactive protein  HIV antibody quantification  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                    43.1                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ...                                   ...                          ...
# 6115                                  NaN                          NaN
# 6116                                  NaN                          NaN
# 6117                                267.0                          NaN
# 6118                                  NaN                          NaN
# 6119                                  NaN                          NaN
#
#       serum sodium  thrombocytocrit  ESR  glutamic-pyruvic transaminase  eGFR  \
# 0              NaN              NaN  NaN                            NaN   NaN
# 1              NaN             0.12  NaN                            NaN   NaN
# 2            137.7              NaN  NaN                           16.0  46.6
# 3              NaN              NaN  NaN                            NaN   NaN
# 4              NaN              NaN  NaN                            NaN   NaN
# ...            ...              ...  ...                            ...   ...
# 6115           NaN              NaN  NaN                            NaN   NaN
# 6116           NaN              NaN  NaN                            NaN   NaN
# 6117         139.3              NaN  NaN                           17.0  88.6
# 6118           NaN              NaN  NaN                            NaN   NaN
# 6119           NaN              NaN  NaN                            NaN   NaN
#
#       creatinine
# 0            NaN
# 1            NaN
# 2          130.0
# 3            NaN
# 4            NaN
# ...          ...
# 6115         NaN
# 6116         NaN
# 6117        77.0
# 6118         NaN
# 6119         NaN
#
# [6120 rows x 81 columns]

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6120 entries, 0 to 6119
# Data columns (total 81 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   PATIENT_ID                                                     6120 non-null   int64
#  1   RE_DATE                                                        6106 non-null   datetime64[ns]
#  2   age                                                            6120 non-null   int64
#  3   gender                                                         6120 non-null   int64
#  4   Admission time                                                 6120 non-null   datetime64[ns]
#  5   Discharge time                                                 6120 non-null   datetime64[ns]
#  6   outcome                                                        6120 non-null   int64
#  7   Hypersensitive cardiac troponinI                               507 non-null    float64
#  8   hemoglobin                                                     975 non-null    float64
#  9   Serum chloride                                                 975 non-null    float64
#  10  Prothrombin time                                               662 non-null    float64
#  11  procalcitonin                                                  459 non-null    float64
#  12  eosinophils(%)                                                 957 non-null    float64
#  13  Interleukin 2 receptor                                         268 non-null    float64
#  14  Alkaline phosphatase                                           930 non-null    float64
#  15  albumin                                                        934 non-null    float64
#  16  basophil(%)                                                    957 non-null    float64
#  17  Interleukin 10                                                 267 non-null    float64
#  18  Total bilirubin                                                930 non-null    float64
#  19  Platelet count                                                 957 non-null    float64
#  20  monocytes(%)                                                   958 non-null    float64
#  21  antithrombin                                                   330 non-null    float64
#  22  Interleukin 8                                                  268 non-null    float64
#  23  indirect bilirubin                                             906 non-null    float64
#  24  Red blood cell distribution width                              923 non-null    float64
#  25  neutrophils(%)                                                 957 non-null    float64
#  26  total protein                                                  931 non-null    float64
#  27  Quantification of Treponema pallidum antibodies                279 non-null    float64
#  28  Prothrombin activity                                           659 non-null    float64
#  29  HBsAg                                                          279 non-null    float64
#  30  mean corpuscular volume                                        957 non-null    float64
#  31  hematocrit                                                     957 non-null    float64
#  32  White blood cell count                                         1127 non-null   float64
#  33  Tumor necrosis factorα                                         268 non-null    float64
#  34  mean corpuscular hemoglobin concentration                      957 non-null    float64
#  35  fibrinogen                                                     566 non-null    float64
#  36  Interleukin 1β                                                 268 non-null    float64
#  37  Urea                                                           936 non-null    float64
#  38  lymphocyte count                                               957 non-null    float64
#  39  PH value                                                       384 non-null    float64
#  40  Red blood cell count                                           1127 non-null   float64
#  41  Eosinophil count                                               957 non-null    float64
#  42  Corrected calcium                                              914 non-null    float64
#  43  Serum potassium                                                980 non-null    float64
#  44  glucose                                                        775 non-null    float64
#  45  neutrophils count                                              957 non-null    float64
#  46  Direct bilirubin                                               930 non-null    float64
#  47  Mean platelet volume                                           862 non-null    float64
#  48  ferritin                                                       283 non-null    float64
#  49  RBC distribution width SD                                      923 non-null    float64
#  50  Thrombin time                                                  566 non-null    float64
#  51  (%)lymphocyte                                                  958 non-null    float64
#  52  HCV antibody quantification                                    279 non-null    float64
#  53  D-D dimer                                                      630 non-null    float64
#  54  Total cholesterol                                              931 non-null    float64
#  55  aspartate aminotransferase                                     935 non-null    float64
#  56  Uric acid                                                      934 non-null    float64
#  57  HCO3-                                                          934 non-null    float64
#  58  calcium                                                        979 non-null    float64
#  59  Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  475 non-null    float64
#  60  Lactate dehydrogenase                                          934 non-null    float64
#  61  platelet large cell ratio                                      862 non-null    float64
#  62  Interleukin 6                                                  272 non-null    float64
#  63  Fibrin degradation products                                    330 non-null    float64
#  64  monocytes count                                                957 non-null    float64
#  65  PLT distribution width                                         862 non-null    float64
#  66  globulin                                                       930 non-null    float64
#  67  γ-glutamyl transpeptidase                                      930 non-null    float64
#  68  International standard ratio                                   659 non-null    float64
#  69  basophil count(#)                                              957 non-null    float64
#  70  2019-nCoV nucleic acid detection                               501 non-null    float64
#  71  mean corpuscular hemoglobin                                    957 non-null    float64
#  72  Activation of partial thromboplastin time                      568 non-null    float64
#  73  High sensitivity C-reactive protein                            737 non-null    float64
#  74  HIV antibody quantification                                    278 non-null    float64
#  75  serum sodium                                                   975 non-null    float64
#  76  thrombocytocrit                                                862 non-null    float64
#  77  ESR                                                            383 non-null    float64
#  78  glutamic-pyruvic transaminase                                  931 non-null    float64
#  79  eGFR                                                           936 non-null    float64
#  80  creatinine                                                     936 non-null    float64
# dtypes: datetime64[ns](3), float64(74), int64(4)
# memory usage: 3.8 MB

# %%
import numpy as np
data3 = data_1.notnull().sum()
data3.sort_values().plot(kind="barh",figsize = (25,25))
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
print(data_1.groupby('outcome').size())
sns.countplot(x="outcome", data=data_1)
# Out:
# outcome
# 0    3215
# 1    2905
# dtype: int64
# <AxesSubplot:xlabel='outcome', ylabel='count'>

# %% [markdown]
# #### Load Test Data

# %% [markdown]
# ##### Creating a new column time_in_hospital

# %%
data_1["time_in_hospital"] = (data_1['Discharge time']- data_1['Admission time']).dt.total_seconds()/(86400.0)
data_1["time_in_hospital"]
# Out:
# 0       17.602338
# 1       17.602338
# 2       17.602338
# 3       17.602338
# 4       17.602338
#           ...
# 6115    10.088160
# 6116    10.088160
# 6117    10.088160
# 6118    10.088160
# 6119    10.088160
# Name: time_in_hospital, Length: 6120, dtype: float64

# %%
test_data = pd.read_excel("C://Users//bhanu//Documents//summer intern//time_series_test_110_preprocess_en.xlsx")  #test data
test_data['PATIENT_ID'] = [i for i in range(1,len(test_data)+1)]
test_data
# Out:
#      PATIENT_ID             RE_DATE  Lactate dehydrogenase  \
# 0             1 2020-02-10 11:15:00                    NaN
# 1             2 2020-02-10 12:07:00                  183.0
# 2             3 2020-02-13 09:35:00                    NaN
# 3             4 2020-02-13 10:06:00                  194.0
# 4             5 2020-02-09 06:56:00                    NaN
# ..          ...                 ...                    ...
# 752         753 2020-02-05 12:36:00                  562.0
# 753         754 2020-02-11 09:40:00                    NaN
# 754         755 2020-02-11 10:04:00                  438.0
# 755         756 2020-02-17 10:00:00                  430.0
# 756         757 2020-02-17 12:05:00                    NaN
#
#      High sensitivity C-reactive protein  (%)lymphocyte      Admission time  \
# 0                                    NaN           28.0 2020-02-09 10:47:24
# 1                                    5.1            NaN 2020-02-09 10:47:24
# 2                                    NaN           28.6 2020-02-09 10:47:24
# 3                                    2.7            NaN 2020-02-09 10:47:24
# 4                                    NaN           28.3 2020-02-09 03:39:47
# ..                                   ...            ...                 ...
# 752                                 78.1            NaN 2020-02-05 00:27:57
# 753                                  NaN            9.7 2020-02-05 00:27:57
# 754                                  NaN            NaN 2020-02-05 00:27:57
# 755                                 31.2            NaN 2020-02-05 00:27:57
# 756                                  NaN           10.0 2020-02-05 00:27:57
#
#          Discharge time  outcome
# 0   2020-02-21 14:51:12        0
# 1   2020-02-21 14:51:12        0
# 2   2020-02-21 14:51:12        0
# 3   2020-02-21 14:51:12        0
# 4   2020-02-21 11:57:40        0
# ..                  ...      ...
# 752 2020-02-22 14:11:47        0
# 753 2020-02-22 14:11:47        0
# 754 2020-02-22 14:11:47        0
# 755 2020-02-22 14:11:47        0
# 756 2020-02-22 14:11:47        0
#
# [757 rows x 8 columns]

# %%
test_data = test_data.sort_values('RE_DATE')
test_data = test_data.sort_values('PATIENT_ID')
test_data.head()
test_data.shape
# Out:
# (757, 8)

# %%
import matplotlib.pyplot as plt
import missingno as msno
msno.bar(test_data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###Imputing missing values with the median of their resepctive columns

# %%
test_data = test_data.fillna(test_data.median())
test_data
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_19868\4175621566.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   test_data = test_data.fillna(test_data.median())
#      PATIENT_ID             RE_DATE  Lactate dehydrogenase  \
# 0             1 2020-02-10 11:15:00                  258.0
# 1             2 2020-02-10 12:07:00                  183.0
# 2             3 2020-02-13 09:35:00                  258.0
# 3             4 2020-02-13 10:06:00                  194.0
# 4             5 2020-02-09 06:56:00                  258.0
# ..          ...                 ...                    ...
# 752         753 2020-02-05 12:36:00                  562.0
# 753         754 2020-02-11 09:40:00                  258.0
# 754         755 2020-02-11 10:04:00                  438.0
# 755         756 2020-02-17 10:00:00                  430.0
# 756         757 2020-02-17 12:05:00                  258.0
#
#      High sensitivity C-reactive protein  (%)lymphocyte      Admission time  \
# 0                                    9.1           28.0 2020-02-09 10:47:24
# 1                                    5.1           17.8 2020-02-09 10:47:24
# 2                                    9.1           28.6 2020-02-09 10:47:24
# 3                                    2.7           17.8 2020-02-09 10:47:24
# 4                                    9.1           28.3 2020-02-09 03:39:47
# ..                                   ...            ...                 ...
# 752                                 78.1           17.8 2020-02-05 00:27:57
# 753                                  9.1            9.7 2020-02-05 00:27:57
# 754                                  9.1           17.8 2020-02-05 00:27:57
# 755                                 31.2           17.8 2020-02-05 00:27:57
# 756                                  9.1           10.0 2020-02-05 00:27:57
#
#          Discharge time  outcome
# 0   2020-02-21 14:51:12        0
# 1   2020-02-21 14:51:12        0
# 2   2020-02-21 14:51:12        0
# 3   2020-02-21 14:51:12        0
# 4   2020-02-21 11:57:40        0
# ..                  ...      ...
# 752 2020-02-22 14:11:47        0
# 753 2020-02-22 14:11:47        0
# 754 2020-02-22 14:11:47        0
# 755 2020-02-22 14:11:47        0
# 756 2020-02-22 14:11:47        0
#
# [757 rows x 8 columns]

# %%
test_data["time_in_hospital"] = (test_data['Discharge time']- test_data['Admission time']).dt.total_seconds()/(86400.0)
test_data.dtypes
# Out:
# PATIENT_ID                                      int64
# RE_DATE                                datetime64[ns]
# Lactate dehydrogenase                         float64
# High sensitivity C-reactive protein           float64
# (%)lymphocyte                                 float64
# Admission time                         datetime64[ns]
# Discharge time                         datetime64[ns]
# outcome                                         int64
# time_in_hospital                              float64
# dtype: object

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6120 entries, 0 to 6119
# Data columns (total 82 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   PATIENT_ID                                                     6120 non-null   int64
#  1   RE_DATE                                                        6106 non-null   datetime64[ns]
#  2   age                                                            6120 non-null   int64
#  3   gender                                                         6120 non-null   int64
#  4   Admission time                                                 6120 non-null   datetime64[ns]
#  5   Discharge time                                                 6120 non-null   datetime64[ns]
#  6   outcome                                                        6120 non-null   int64
#  7   Hypersensitive cardiac troponinI                               507 non-null    float64
#  8   hemoglobin                                                     975 non-null    float64
#  9   Serum chloride                                                 975 non-null    float64
#  10  Prothrombin time                                               662 non-null    float64
#  11  procalcitonin                                                  459 non-null    float64
#  12  eosinophils(%)                                                 957 non-null    float64
#  13  Interleukin 2 receptor                                         268 non-null    float64
#  14  Alkaline phosphatase                                           930 non-null    float64
#  15  albumin                                                        934 non-null    float64
#  16  basophil(%)                                                    957 non-null    float64
#  17  Interleukin 10                                                 267 non-null    float64
#  18  Total bilirubin                                                930 non-null    float64
#  19  Platelet count                                                 957 non-null    float64
#  20  monocytes(%)                                                   958 non-null    float64
#  21  antithrombin                                                   330 non-null    float64
#  22  Interleukin 8                                                  268 non-null    float64
#  23  indirect bilirubin                                             906 non-null    float64
#  24  Red blood cell distribution width                              923 non-null    float64
#  25  neutrophils(%)                                                 957 non-null    float64
#  26  total protein                                                  931 non-null    float64
#  27  Quantification of Treponema pallidum antibodies                279 non-null    float64
#  28  Prothrombin activity                                           659 non-null    float64
#  29  HBsAg                                                          279 non-null    float64
#  30  mean corpuscular volume                                        957 non-null    float64
#  31  hematocrit                                                     957 non-null    float64
#  32  White blood cell count                                         1127 non-null   float64
#  33  Tumor necrosis factorα                                         268 non-null    float64
#  34  mean corpuscular hemoglobin concentration                      957 non-null    float64
#  35  fibrinogen                                                     566 non-null    float64
#  36  Interleukin 1β                                                 268 non-null    float64
#  37  Urea                                                           936 non-null    float64
#  38  lymphocyte count                                               957 non-null    float64
#  39  PH value                                                       384 non-null    float64
#  40  Red blood cell count                                           1127 non-null   float64
#  41  Eosinophil count                                               957 non-null    float64
#  42  Corrected calcium                                              914 non-null    float64
#  43  Serum potassium                                                980 non-null    float64
#  44  glucose                                                        775 non-null    float64
#  45  neutrophils count                                              957 non-null    float64
#  46  Direct bilirubin                                               930 non-null    float64
#  47  Mean platelet volume                                           862 non-null    float64
#  48  ferritin                                                       283 non-null    float64
#  49  RBC distribution width SD                                      923 non-null    float64
#  50  Thrombin time                                                  566 non-null    float64
#  51  (%)lymphocyte                                                  958 non-null    float64
#  52  HCV antibody quantification                                    279 non-null    float64
#  53  D-D dimer                                                      630 non-null    float64
#  54  Total cholesterol                                              931 non-null    float64
#  55  aspartate aminotransferase                                     935 non-null    float64
#  56  Uric acid                                                      934 non-null    float64
#  57  HCO3-                                                          934 non-null    float64
#  58  calcium                                                        979 non-null    float64
#  59  Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  475 non-null    float64
#  60  Lactate dehydrogenase                                          934 non-null    float64
#  61  platelet large cell ratio                                      862 non-null    float64
#  62  Interleukin 6                                                  272 non-null    float64
#  63  Fibrin degradation products                                    330 non-null    float64
#  64  monocytes count                                                957 non-null    float64
#  65  PLT distribution width                                         862 non-null    float64
#  66  globulin                                                       930 non-null    float64
#  67  γ-glutamyl transpeptidase                                      930 non-null    float64
#  68  International standard ratio                                   659 non-null    float64
#  69  basophil count(#)                                              957 non-null    float64
#  70  2019-nCoV nucleic acid detection                               501 non-null    float64
#  71  mean corpuscular hemoglobin                                    957 non-null    float64
#  72  Activation of partial thromboplastin time                      568 non-null    float64
#  73  High sensitivity C-reactive protein                            737 non-null    float64
#  74  HIV antibody quantification                                    278 non-null    float64
#  75  serum sodium                                                   975 non-null    float64
#  76  thrombocytocrit                                                862 non-null    float64
#  77  ESR                                                            383 non-null    float64
#  78  glutamic-pyruvic transaminase                                  931 non-null    float64
#  79  eGFR                                                           936 non-null    float64
#  80  creatinine                                                     936 non-null    float64
#  81  time_in_hospital                                               6120 non-null   float64
# dtypes: datetime64[ns](3), float64(75), int64(4)
# memory usage: 3.9 MB

# %% [markdown]
# ##  TEST 1: prediction using the same features as test data

# %%
#taking the same data features as of test dataset
train_data = data_1[['PATIENT_ID','Admission time','Discharge time','outcome','High sensitivity C-reactive protein','(%)lymphocyte','Lactate dehydrogenase',"time_in_hospital"]]
train_data = train_data.fillna(train_data.median())
train_data.shape
test_data = test_data[['PATIENT_ID','Admission time','Discharge time','outcome','High sensitivity C-reactive protein','(%)lymphocyte','Lactate dehydrogenase',"time_in_hospital"]]
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_19868\816518180.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   train_data = train_data.fillna(train_data.median())

# %%
print("train_data types:\n",train_data.dtypes)
print("test_data types:\n",test_data.dtypes)
train_data.index = np.arange(1, len(train_data)+1)
train_data['PATIENT_ID']=train_data.index
test_data.index = np.arange(1, len(test_data)+1)
test_data['PATIENT_ID']=test_data.index
# Out:
# train_data types:
#  PATIENT_ID                                      int64
# Admission time                         datetime64[ns]
# Discharge time                         datetime64[ns]
# outcome                                         int64
# High sensitivity C-reactive protein           float64
# (%)lymphocyte                                 float64
# Lactate dehydrogenase                         float64
# time_in_hospital                              float64
# dtype: object
# test_data types:
#  PATIENT_ID                                      int64
# Admission time                         datetime64[ns]
# Discharge time                         datetime64[ns]
# outcome                                         int64
# High sensitivity C-reactive protein           float64
# (%)lymphocyte                                 float64
# Lactate dehydrogenase                         float64
# time_in_hospital                              float64
# dtype: object
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_19868\94310345.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['PATIENT_ID']=test_data.index

# %% [markdown]
# ## Decision Tree

# %%
features_column =  ['Lactate dehydrogenase', '(%)lymphocyte','High sensitivity C-reactive protein',"time_in_hospital"]
target_column = ['outcome']
Xtrain_data = train_data[features_column]
Ytrain_data = train_data[target_column]
Xtest_data = test_data[features_column]
Ytest_data = test_data[target_column]
model_DT = DecisionTreeClassifier(criterion='entropy',splitter='best',random_state=0)
model_DT= model_DT.fit(Xtrain_data,Ytrain_data)
target_pred = model_DT.predict(Xtest_data)

#print(target_pred)
print("accuracy DT",metrics.accuracy_score(Ytest_data, target_pred))
# Out:
# accuracy DT 0.7807133421400264

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model_RF = RandomForestClassifier(n_estimators = 100,criterion='entropy',random_state=0)
model_RF = model_RF.fit(Xtrain_data,Ytrain_data)
target_pred_RF = model_RF.predict(Xtest_data)
print("accuracy RF",metrics.accuracy_score(Ytest_data, target_pred_RF))
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_19868\2120585336.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_RF = model_RF.fit(Xtrain_data,Ytrain_data)
# accuracy RF 0.8441215323645971

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model_GB = GaussianNB()
model_GB = model_GB.fit(Xtrain_data,Ytrain_data)
target_pred_GB = model_GB.predict(Xtest_data)
print("accuracy SVM",metrics.accuracy_score(Ytest_data, target_pred_GB))
# Out:
# accuracy SVM 0.6142668428005285
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
model_LR = LogisticRegression(solver='liblinear', random_state=0)
model_LR = model_LR.fit(Xtrain_data,Ytrain_data)
target_pred_LR = model_LR.predict(Xtest_data)
metrics.accuracy_score(Ytest_data, target_pred_LR)
# Out:
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8124174372523117

# %%
confusion_matrix(Ytest_data,target_pred_LR)
# Out:
# array([[482,   3],
#        [139, 133]], dtype=int64)

# %% [markdown]
# # Support Vector Machines

# %%
from sklearn.svm import SVC

model_SVM = SVC()
model_SVM  = model_SVM.fit(Xtrain_data,Ytrain_data)
target_pred_SVM = model_SVM.predict(Xtest_data)
metrics.accuracy_score(Ytest_data, target_pred_SVM)
# Out:
# C:\Users\bhanu\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.774108322324967

# %%
## for given test and train
acc_results = [(metrics.accuracy_score(Ytest_data, target_pred))*100,(metrics.accuracy_score(Ytest_data, target_pred_RF))*100,(metrics.accuracy_score(Ytest_data, target_pred_SVM))*100]
acc_results
# Out:
# [78.07133421400265, 84.4121532364597, 77.4108322324967]

# %% [markdown]
# #### The  graph below shows the accuracy using the different classification algorithms

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

fig = plt.figure(figsize=(3, 2), dpi=130)
ax = fig.add_axes([0,0,1,1])
langs = ['DT', 'RF','SVM']

ax.bar(langs,acc_results)
plt.show()
print(acc_results)
# Out:
# [78.07133421400265, 84.4121532364597, 77.4108322324967]

# %% [markdown]
# ## Test 2: Models for train test split data - Biomarkers selected which truly determine the mortality

# %%
# training data for 7 selected biomarkers

train_data_new = data_1[['PATIENT_ID','RE_DATE','Admission time','Discharge time','outcome','2019-nCoV nucleic acid detection','Platelet count','D-D dimer','Hypersensitive cardiac troponinI','lymphocyte count','creatinine','White blood cell count','neutrophils count','Urea','time_in_hospital']]

# %%
train_data_new.index = np.arange(1, len(train_data_new)+1)
train_data_new['PATIENT_ID']=train_data_new.index

train_data_new = train_data_new.fillna(train_data_new.mean())
train_data_new.head()
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_19868\1263304710.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_new['PATIENT_ID']=train_data_new.index
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_19868\1263304710.py:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   train_data_new = train_data_new.fillna(train_data_new.mean())
#    PATIENT_ID             RE_DATE      Admission time      Discharge time  \
# 1           1 2020-01-31 01:09:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 2           2 2020-01-31 01:25:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 3           3 2020-01-31 01:44:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 4           4 2020-01-31 01:45:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 5           5 2020-01-31 01:56:00 2020-01-30 22:12:47 2020-02-17 12:40:09
#
#    outcome  2019-nCoV nucleic acid detection  Platelet count  D-D dimer  \
# 1        0                              -1.0      184.310345   7.943413
# 2        0                              -1.0      105.000000   7.943413
# 3        0                              -1.0      184.310345   7.943413
# 4        0                              -1.0      184.310345   2.200000
# 5        0                              -1.0      184.310345   7.943413
#
#    Hypersensitive cardiac troponinI  lymphocyte count  creatinine  \
# 1                        1223.22998          1.016782  109.933761
# 2                        1223.22998          0.800000  109.933761
# 3                        1223.22998          1.016782  130.000000
# 4                        1223.22998          1.016782  109.933761
# 5                          19.90000          1.016782  109.933761
#
#    White blood cell count  neutrophils count      Urea  time_in_hospital
# 1               15.599441           7.809582  9.589241         17.602338
# 2                3.540000           2.330000  9.589241         17.602338
# 3               15.599441           7.809582  8.500000         17.602338
# 4               15.599441           7.809582  9.589241         17.602338
# 5               15.599441           7.809582  9.589241         17.602338

# %%
features = ['PATIENT_ID','2019-nCoV nucleic acid detection','Platelet count','D-D dimer','Hypersensitive cardiac troponinI','lymphocyte count','creatinine','White blood cell count','neutrophils count','Urea','time_in_hospital']
target = ['outcome']
X = train_data_new[features]
y = train_data_new[target]
X
# Out:
#       PATIENT_ID  2019-nCoV nucleic acid detection  Platelet count  D-D dimer  \
# 1              1                              -1.0      184.310345   7.943413
# 2              2                              -1.0      105.000000   7.943413
# 3              3                              -1.0      184.310345   7.943413
# 4              4                              -1.0      184.310345   2.200000
# 5              5                              -1.0      184.310345   7.943413
# ...          ...                               ...             ...        ...
# 6116        6116                              -1.0      184.310345   7.943413
# 6117        6117                              -1.0      184.310345   7.943413
# 6118        6118                              -1.0      184.310345   7.943413
# 6119        6119                              -1.0       17.000000   7.943413
# 6120        6120                              -1.0      184.310345  21.000000
#
#       Hypersensitive cardiac troponinI  lymphocyte count  creatinine  \
# 1                           1223.22998          1.016782  109.933761
# 2                           1223.22998          0.800000  109.933761
# 3                           1223.22998          1.016782  130.000000
# 4                           1223.22998          1.016782  109.933761
# 5                             19.90000          1.016782  109.933761
# ...                                ...               ...         ...
# 6116                          84.90000          1.016782  109.933761
# 6117                        1223.22998          1.016782  109.933761
# 6118                        1223.22998          1.016782   77.000000
# 6119                        1223.22998          0.550000  109.933761
# 6120                        1223.22998          1.016782  109.933761
#
#       White blood cell count  neutrophils count      Urea  time_in_hospital
# 1                  15.599441           7.809582  9.589241         17.602338
# 2                   3.540000           2.330000  9.589241         17.602338
# 3                  15.599441           7.809582  8.500000         17.602338
# 4                  15.599441           7.809582  9.589241         17.602338
# 5                  15.599441           7.809582  9.589241         17.602338
# ...                      ...                ...       ...               ...
# 6116               15.599441           7.809582  9.589241         10.088160
# 6117               15.599441           7.809582  9.589241         10.088160
# 6118               15.599441           7.809582  9.800000         10.088160
# 6119                8.250000           7.570000  9.589241         10.088160
# 6120               15.599441           7.809582  9.589241         10.088160
#
# [6120 rows x 11 columns]

# %%
import pandas
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

X = train_data_new[features]
Y = train_data_new[target].values.ravel()
# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('DT', DecisionTreeClassifier()))
models.append(('SVM', SVC()))
models.append(('RF', RandomForestClassifier(n_estimators = 100,criterion='entropy',random_state=0)))
# models.append(('LR',LogisticRegression()))
# evaluate each model in turn
results = []
names = []

scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=7,shuffle=True)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
    
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
#plt.bar(results,height=100)
plt.subplot()
ax.set_xticklabels(names)
plt.show()
# Out:
# DT: 0.999837 (0.000490)
# SVM: 0.999020 (0.001084)
# RF: 1.000000 (0.000000)

# %%
res = [99.7927,98.6558,100.0]

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['DT','SVM','RF']

ax.bar(langs,res)
plt.show()

# %% [markdown]
# ## Combined set

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6120 entries, 0 to 6119
# Data columns (total 82 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   PATIENT_ID                                                     6120 non-null   int64
#  1   RE_DATE                                                        6106 non-null   datetime64[ns]
#  2   age                                                            6120 non-null   int64
#  3   gender                                                         6120 non-null   int64
#  4   Admission time                                                 6120 non-null   datetime64[ns]
#  5   Discharge time                                                 6120 non-null   datetime64[ns]
#  6   outcome                                                        6120 non-null   int64
#  7   Hypersensitive cardiac troponinI                               507 non-null    float64
#  8   hemoglobin                                                     975 non-null    float64
#  9   Serum chloride                                                 975 non-null    float64
#  10  Prothrombin time                                               662 non-null    float64
#  11  procalcitonin                                                  459 non-null    float64
#  12  eosinophils(%)                                                 957 non-null    float64
#  13  Interleukin 2 receptor                                         268 non-null    float64
#  14  Alkaline phosphatase                                           930 non-null    float64
#  15  albumin                                                        934 non-null    float64
#  16  basophil(%)                                                    957 non-null    float64
#  17  Interleukin 10                                                 267 non-null    float64
#  18  Total bilirubin                                                930 non-null    float64
#  19  Platelet count                                                 957 non-null    float64
#  20  monocytes(%)                                                   958 non-null    float64
#  21  antithrombin                                                   330 non-null    float64
#  22  Interleukin 8                                                  268 non-null    float64
#  23  indirect bilirubin                                             906 non-null    float64
#  24  Red blood cell distribution width                              923 non-null    float64
#  25  neutrophils(%)                                                 957 non-null    float64
#  26  total protein                                                  931 non-null    float64
#  27  Quantification of Treponema pallidum antibodies                279 non-null    float64
#  28  Prothrombin activity                                           659 non-null    float64
#  29  HBsAg                                                          279 non-null    float64
#  30  mean corpuscular volume                                        957 non-null    float64
#  31  hematocrit                                                     957 non-null    float64
#  32  White blood cell count                                         1127 non-null   float64
#  33  Tumor necrosis factorα                                         268 non-null    float64
#  34  mean corpuscular hemoglobin concentration                      957 non-null    float64
#  35  fibrinogen                                                     566 non-null    float64
#  36  Interleukin 1β                                                 268 non-null    float64
#  37  Urea                                                           936 non-null    float64
#  38  lymphocyte count                                               957 non-null    float64
#  39  PH value                                                       384 non-null    float64
#  40  Red blood cell count                                           1127 non-null   float64
#  41  Eosinophil count                                               957 non-null    float64
#  42  Corrected calcium                                              914 non-null    float64
#  43  Serum potassium                                                980 non-null    float64
#  44  glucose                                                        775 non-null    float64
#  45  neutrophils count                                              957 non-null    float64
#  46  Direct bilirubin                                               930 non-null    float64
#  47  Mean platelet volume                                           862 non-null    float64
#  48  ferritin                                                       283 non-null    float64
#  49  RBC distribution width SD                                      923 non-null    float64
#  50  Thrombin time                                                  566 non-null    float64
#  51  (%)lymphocyte                                                  958 non-null    float64
#  52  HCV antibody quantification                                    279 non-null    float64
#  53  D-D dimer                                                      630 non-null    float64
#  54  Total cholesterol                                              931 non-null    float64
#  55  aspartate aminotransferase                                     935 non-null    float64
#  56  Uric acid                                                      934 non-null    float64
#  57  HCO3-                                                          934 non-null    float64
#  58  calcium                                                        979 non-null    float64
#  59  Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  475 non-null    float64
#  60  Lactate dehydrogenase                                          934 non-null    float64
#  61  platelet large cell ratio                                      862 non-null    float64
#  62  Interleukin 6                                                  272 non-null    float64
#  63  Fibrin degradation products                                    330 non-null    float64
#  64  monocytes count                                                957 non-null    float64
#  65  PLT distribution width                                         862 non-null    float64
#  66  globulin                                                       930 non-null    float64
#  67  γ-glutamyl transpeptidase                                      930 non-null    float64
#  68  International standard ratio                                   659 non-null    float64
#  69  basophil count(#)                                              957 non-null    float64
#  70  2019-nCoV nucleic acid detection                               501 non-null    float64
#  71  mean corpuscular hemoglobin                                    957 non-null    float64
#  72  Activation of partial thromboplastin time                      568 non-null    float64
#  73  High sensitivity C-reactive protein                            737 non-null    float64
#  74  HIV antibody quantification                                    278 non-null    float64
#  75  serum sodium                                                   975 non-null    float64
#  76  thrombocytocrit                                                862 non-null    float64
#  77  ESR                                                            383 non-null    float64
#  78  glutamic-pyruvic transaminase                                  931 non-null    float64
#  79  eGFR                                                           936 non-null    float64
#  80  creatinine                                                     936 non-null    float64
#  81  time_in_hospital                                               6120 non-null   float64
# dtypes: datetime64[ns](3), float64(75), int64(4)
# memory usage: 3.9 MB

# %%
train_data_combined = data_1[['PATIENT_ID','RE_DATE','Admission time','Discharge time','outcome','2019-nCoV nucleic acid detection','Platelet count','D-D dimer','Hypersensitive cardiac troponinI','lymphocyte count','creatinine','White blood cell count','neutrophils count','Urea','High sensitivity C-reactive protein','(%)lymphocyte','Lactate dehydrogenase']]
train_data_combined.index = np.arange(1, len(train_data_combined)+1)
train_data_combined['PATIENT_ID']=train_data_combined.index
# train_data_combined = train_data_combined.fillna(train_data_combined.median())
train_data_combined.head()
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_8032\3131317564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_combined['PATIENT_ID']=train_data_combined.index
#    PATIENT_ID             RE_DATE      Admission time      Discharge time  \
# 1           1 2020-01-31 01:09:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 2           2 2020-01-31 01:25:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 3           3 2020-01-31 01:44:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 4           4 2020-01-31 01:45:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 5           5 2020-01-31 01:56:00 2020-01-30 22:12:47 2020-02-17 12:40:09
#
#    outcome  2019-nCoV nucleic acid detection  Platelet count  D-D dimer  \
# 1        0                               NaN             NaN        NaN
# 2        0                               NaN           105.0        NaN
# 3        0                               NaN             NaN        NaN
# 4        0                               NaN             NaN        2.2
# 5        0                               NaN             NaN        NaN
#
#    Hypersensitive cardiac troponinI  lymphocyte count  creatinine  \
# 1                               NaN               NaN         NaN
# 2                               NaN               0.8         NaN
# 3                               NaN               NaN       130.0
# 4                               NaN               NaN         NaN
# 5                              19.9               NaN         NaN
#
#    White blood cell count  neutrophils count  Urea  \
# 1                     NaN                NaN   NaN
# 2                    3.54               2.33   NaN
# 3                     NaN                NaN   8.5
# 4                     NaN                NaN   NaN
# 5                     NaN                NaN   NaN
#
#    High sensitivity C-reactive protein  (%)lymphocyte  Lactate dehydrogenase
# 1                                  NaN            NaN                    NaN
# 2                                  NaN           22.6                    NaN
# 3                                 43.1            NaN                  306.0
# 4                                  NaN            NaN                    NaN
# 5                                  NaN            NaN                    NaN

# %%
train_data_combined["time_in_hospital"] = pd.to_numeric(train_data_combined['Discharge time']- train_data_combined['Admission time'])
train_data_new.dtypes
values4 = {'2019-nCoV nucleic acid detection':train_data_combined['2019-nCoV nucleic acid detection'].median(),'Platelet count':train_data_combined['Platelet count'].median(),'D-D dimer':train_data_combined['D-D dimer'].median(),'Hypersensitive cardiac troponinI':train_data_combined['Hypersensitive cardiac troponinI'].median(),'lymphocyte count':train_data_combined['lymphocyte count'].median(),'creatinine':train_data_combined['creatinine'].median(),'White blood cell count':train_data_combined['White blood cell count'].median(),'neutrophils count':train_data_combined['neutrophils count'].median(),'Urea':train_data_combined['Urea'].median(),'High sensitivity C-reactive protein':train_data_combined['High sensitivity C-reactive protein'].median(),'(%)lymphocyte':train_data_combined['(%)lymphocyte'].median(),'Lactate dehydrogenase':train_data_combined['Lactate dehydrogenase'].median()}
train_data_combined = train_data_combined.fillna(value = values4)
train_data_combined.head()
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_8032\1449270196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_combined["time_in_hospital"] = pd.to_numeric(train_data_combined['Discharge time']- train_data_combined['Admission time'])
#    PATIENT_ID             RE_DATE      Admission time      Discharge time  \
# 1           1 2020-01-31 01:09:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 2           2 2020-01-31 01:25:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 3           3 2020-01-31 01:44:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 4           4 2020-01-31 01:45:00 2020-01-30 22:12:47 2020-02-17 12:40:09
# 5           5 2020-01-31 01:56:00 2020-01-30 22:12:47 2020-02-17 12:40:09
#
#    outcome  2019-nCoV nucleic acid detection  Platelet count  D-D dimer  \
# 1        0                              -1.0           178.0      2.155
# 2        0                              -1.0           105.0      2.155
# 3        0                              -1.0           178.0      2.155
# 4        0                              -1.0           178.0      2.200
# 5        0                              -1.0           178.0      2.155
#
#    Hypersensitive cardiac troponinI  lymphocyte count  creatinine  \
# 1                              20.6               0.8        76.0
# 2                              20.6               0.8        76.0
# 3                              20.6               0.8       130.0
# 4                              20.6               0.8        76.0
# 5                              19.9               0.8        76.0
#
#    White blood cell count  neutrophils count   Urea  \
# 1                    7.72               5.85  5.985
# 2                    3.54               2.33  5.985
# 3                    7.72               5.85  8.500
# 4                    7.72               5.85  5.985
# 5                    7.72               5.85  5.985
#
#    High sensitivity C-reactive protein  (%)lymphocyte  Lactate dehydrogenase  \
# 1                                 51.5          11.45                  340.0
# 2                                 51.5          22.60                  340.0
# 3                                 43.1          11.45                  306.0
# 4                                 51.5          11.45                  340.0
# 5                                 51.5          11.45                  340.0
#
#    time_in_hospital
# 1  1520842000000000
# 2  1520842000000000
# 3  1520842000000000
# 4  1520842000000000
# 5  1520842000000000

# %%
features2 = ['PATIENT_ID','2019-nCoV nucleic acid detection','Platelet count','D-D dimer','Hypersensitive cardiac troponinI','lymphocyte count','creatinine','White blood cell count','neutrophils count','Urea','time_in_hospital','Lactate dehydrogenase', '(%)lymphocyte','High sensitivity C-reactive protein']
target2 = ['outcome']
X2 = train_data_combined[features2]
y2 = train_data_combined[target2]

# %%
from sklearn.ensemble import RandomForestClassifier
model_RF = RandomForestClassifier(n_estimators = 100,criterion='entropy',random_state=0)

# %%
import pandas
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
X = train_data_combined[features2]
Y = train_data_combined[target2].values.ravel()
# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('DT', DecisionTreeClassifier()))
models.append(('SVM', SVC()))
models.append(('RF', RandomForestClassifier(n_estimators = 100,criterion='entropy',random_state=0)
))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed,shuffle=True)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
#plt.bar(results,height=100)
plt.subplot()
ax.set_xticklabels(names)
plt.show()
# Out:
# DT: 0.999837 (0.000490)
# SVM: 0.766993 (0.018036)
# RF: 1.000000 (0.000000)

# %% [markdown]
# ### The accuracy we get by implementing all the classification algortithms by using all the attributes present in the dataset

# %%
qw = [99.7297, 71.4225,100.00]
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['DT','SVM','RF']

ax.bar(langs,qw)
plt.show()

# %% [markdown]
# ### RQ 2

# %% [markdown]
# ### Feature Selection using XGBoost

# %%
# feature selection from all the biomarkers
feature = ['Hypersensitive cardiac troponinI',
       'hemoglobin', 'Serum chloride', 'Prothrombin time', 'procalcitonin',
       'eosinophils(%)', 'Interleukin 2 receptor', 'Alkaline phosphatase',
       'albumin', 'basophil(%)', 'Interleukin 10', 'Total bilirubin',
       'Platelet count', 'monocytes(%)', 'antithrombin', 'Interleukin 8',
       'indirect bilirubin', 'Red blood cell distribution width ',
       'neutrophils(%)', 'total protein',
       'Quantification of Treponema pallidum antibodies',
       'Prothrombin activity', 'HBsAg', 'mean corpuscular volume',
       'hematocrit', 'White blood cell count', 'Tumor necrosis factorα',
       'mean corpuscular hemoglobin concentration', 'fibrinogen',
       'Interleukin 1β', 'Urea', 'lymphocyte count', 'PH value',
       'Red blood cell count', 'Eosinophil count', 'Corrected calcium',
       'Serum potassium', 'glucose', 'neutrophils count', 'Direct bilirubin',
       'Mean platelet volume', 'ferritin', 'RBC distribution width SD',
       'Thrombin time', '(%)lymphocyte', 'HCV antibody quantification',
       'D-D dimer', 'Total cholesterol', 'aspartate aminotransferase',
       'Uric acid', 'HCO3-', 'calcium',
       'Amino-terminal brain natriuretic peptide precursor(NT-proBNP)',
       'Lactate dehydrogenase', 'platelet large cell ratio ', 'Interleukin 6',
       'Fibrin degradation products', 'monocytes count',
       'PLT distribution width', 'globulin', 'γ-glutamyl transpeptidase',
       'International standard ratio', 'basophil count(#)',
       '2019-nCoV nucleic acid detection', 'mean corpuscular hemoglobin ',
       'Activation of partial thromboplastin time',
       'High sensitivity C-reactive protein', 'HIV antibody quantification',
       'serum sodium', 'thrombocytocrit', 'ESR',
       'glutamic-pyruvic transaminase', 'eGFR', 'creatinine']
outcome = ['outcome']
Xdata = data_1[feature]
Ydata = data_1[outcome]
Xdata = Xdata.fillna(Xdata.median())
Xdata.head()
# Out:
#    Hypersensitive cardiac troponinI  hemoglobin  Serum chloride  \
# 0                              20.6       125.0           102.1
# 1                              20.6       136.0           102.1
# 2                              20.6       125.0           103.1
# 3                              20.6       125.0           102.1
# 4                              19.9       125.0           102.1
#
#    Prothrombin time  procalcitonin  eosinophils(%)  Interleukin 2 receptor  \
# 0              14.8           0.10             0.1                   676.5
# 1              14.8           0.10             0.6                   676.5
# 2              14.8           0.10             0.1                   676.5
# 3              13.9           0.10             0.1                   676.5
# 4              14.8           0.09             0.1                   676.5
#
#    Alkaline phosphatase  albumin  basophil(%)  ...  \
# 0                  69.5     32.2          0.2  ...
# 1                  69.5     32.2          0.3  ...
# 2                  46.0     33.3          0.2  ...
# 3                  69.5     32.2          0.2  ...
# 4                  69.5     32.2          0.2  ...
#
#    mean corpuscular hemoglobin   Activation of partial thromboplastin time  \
# 0                          30.9                                       39.2
# 1                          31.9                                       39.2
# 2                          30.9                                       39.2
# 3                          30.9                                       39.2
# 4                          30.9                                       39.2
#
#    High sensitivity C-reactive protein  HIV antibody quantification  \
# 0                                 51.5                         0.09
# 1                                 51.5                         0.09
# 2                                 43.1                         0.09
# 3                                 51.5                         0.09
# 4                                 51.5                         0.09
#
#    serum sodium  thrombocytocrit   ESR  glutamic-pyruvic transaminase  eGFR  \
# 0         140.4             0.21  28.0                           24.0  87.9
# 1         140.4             0.12  28.0                           24.0  87.9
# 2         137.7             0.21  28.0                           16.0  46.6
# 3         140.4             0.21  28.0                           24.0  87.9
# 4         140.4             0.21  28.0                           24.0  87.9
#
#    creatinine
# 0        76.0
# 1        76.0
# 2       130.0
# 3        76.0
# 4        76.0
#
# [5 rows x 74 columns]

# %%
# !pip install xgboost
# !pip install shap
import xgboost
import shap
# load JS visualization code to notebook
shap.initjs()
# train XGBoost model
model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(Xdata, label=Ydata), 100)
# explain the model's predictions using SHAP values
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(Xdata)
shap.summary_plot(shap_values, Xdata, plot_type="bar")
# Out:
# Requirement already satisfied: xgboost in c:\users\bhanu\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy in c:\users\bhanu\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\bhanu\anaconda3\lib\site-packages (from xgboost) (1.9.1)
# Requirement already satisfied: shap in c:\users\bhanu\anaconda3\lib\site-packages (0.41.0)
# Requirement already satisfied: cloudpickle in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: pandas in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (1.4.4)
# Requirement already satisfied: numba in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (0.55.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: scikit-learn in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (1.0.2)
# Requirement already satisfied: numpy in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: scipy in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (1.9.1)
# Requirement already satisfied: packaging>20.9 in c:\users\bhanu\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bhanu\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\bhanu\anaconda3\lib\site-packages (from tqdm>4.25.0->shap) (0.4.5)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\bhanu\anaconda3\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\bhanu\anaconda3\lib\site-packages (from numba->shap) (63.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bhanu\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bhanu\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\bhanu\anaconda3\lib\site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bhanu\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\bhanu\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ### Prediction using top 10 features from XGBoost feature selection model

# %%
fs = ['Lactate dehydrogenase','neutrophils(%)','High sensitivity C-reactive protein','Amino-terminal brain natriuretic peptide precursor(NT-proBNP)','(%)lymphocyte','D-D dimer','Urea','glucose','Prothrombin time','Platelet count','procalcitonin']
ts = ['outcome']
Xs = Xdata[fs]
Ys = Ydata[ts]
Xs.head()
# Out:
#    Lactate dehydrogenase  neutrophils(%)  High sensitivity C-reactive protein  \
# 0                  340.0            82.4                                 51.5
# 1                  340.0            65.8                                 51.5
# 2                  306.0            82.4                                 43.1
# 3                  340.0            82.4                                 51.5
# 4                  340.0            82.4                                 51.5
#
#    Amino-terminal brain natriuretic peptide precursor(NT-proBNP)  \
# 0                                              585.0
# 1                                              585.0
# 2                                              585.0
# 3                                              585.0
# 4                                               60.0
#
#    (%)lymphocyte  D-D dimer   Urea  glucose  Prothrombin time  Platelet count  \
# 0          11.45      2.155  5.985     6.99              14.8           178.0
# 1          22.60      2.155  5.985     6.99              14.8           105.0
# 2          11.45      2.155  8.500     6.99              14.8           178.0
# 3          11.45      2.200  5.985     6.99              13.9           178.0
# 4          11.45      2.155  5.985     7.35              14.8           178.0
#
#    procalcitonin
# 0           0.10
# 1           0.10
# 2           0.10
# 3           0.10
# 4           0.09

# %% [markdown]
# #### Decision Tree, Random Forest and SVM model validation using Cross Validation

# %%
import pandas
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# Data
Xs = Xdata[fs]
Ys = Ydata[ts]
# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []

models.append(('DT', DecisionTreeClassifier()))
models.append(('SVM', SVC()))
models.append(('RF', RandomForestClassifier(n_estimators = 100,criterion='entropy',random_state=0)))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed,shuffle=True)
	cv_results = model_selection.cross_val_score(model, Xs, Ys, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
#plt.bar(results,height=100)
plt.subplot()
ax.set_xticklabels(names)
plt.show()
# Out:
# DT: 0.740196 (0.014245)
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# SVM: 0.624510 (0.025699)
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RF: 0.756863 (0.015515)

# %%
r = [67.2546,53.3926,68.5917]
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['DT','SVM', 'RF']

ax.bar(langs,r)
plt.show()
